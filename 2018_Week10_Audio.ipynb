# %% [markdown]
# <a href="https://colab.research.google.com/github/tjwei/NDHU_AM1130/blob/master/2018_Week10_Audio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
rate = 36
t = np.arange(0, 1.1, 1/rate)
y = np.sin(t * 32 * 2* np.pi)
plt.plot(y)

# %%
from IPython.display import Audio

# %%
import numpy as np
rate = 48000
t = np.arange(0, 1, 1/rate)
y = np.sin(t * 14000 * 2* np.pi)
Audio(data=y, rate=rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
