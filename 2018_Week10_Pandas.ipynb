# %% [markdown]
# <a href="https://colab.research.google.com/github/tjwei/NDHU_AM1130/blob/master/2018_Week10_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("http://stats.moe.gov.tw/files/detail/106/106_student.csv", thousands=',');

# %%
df.head()
# Out:
#    學校代碼    學校名稱 日間∕進修別   等級別 一年級男生  一年級女生 二年級男生  二年級女生 三年級男生  三年級女生  ...   \
# 0     1  國立政治大學    D 日  D 博士    90     82   102     59    85     58  ...
# 1     1  國立政治大學    D 日  M 碩士   685    760   571    699   369    456  ...
# 2     1  國立政治大學    D 日  B 學士   897  1,299   888  1,348   997  1,226  ...
# 3     1  國立政治大學    N 職  M 碩士   295    278   264    280   163    185  ...
# 4     2  國立清華大學    D 日  D 博士   220     77   211     83   196     58  ...
#
#   五年級男生 五年級女生 六年級男生 六年級女生 七年級男生 七年級女生 延修生男生 延修生女生    縣市名稱   體系別
# 0    66    54    72    37    81    35     -     -  30 臺北市  1 一般
# 1     -     -     -     -     -     -     -     -  30 臺北市  1 一般
# 2     -     -     -     -     -     -   294   453  30 臺北市  1 一般
# 3    50    49     -     -     -     -     -     -  30 臺北市  1 一般
# 4   138    43   119    45   186    69     -     -  18 新竹市  1 一般
#
# [5 rows x 22 columns]

# %%
df.tail()
# Out:
#      學校代碼        學校名稱 日間∕進修別   等級別 一年級男生 一年級女生 二年級男生 二年級女生 三年級男生 三年級女生  ...   \
# 833  1292  新生醫護管理專科學校    N 修  2 二專    22    34     9    22     -     -  ...
# 834  3002      臺北市立大學    D 日  D 博士    18    13    18    14    12    24  ...
# 835  3002      臺北市立大學    D 日  M 碩士   132   241   108   210    79   171  ...
# 836  3002      臺北市立大學    D 日  B 學士   580   710   574   680   548   705  ...
# 837  3002      臺北市立大學    N 職  M 碩士    98   250   102   224    38   100  ...
#
#     五年級男生 五年級女生 六年級男生 六年級女生 七年級男生 七年級女生 延修生男生 延修生女生    縣市名稱   體系別
# 833     -     -     -     -     -     -     -     -  03 桃園市  2 技職
# 834    11    14     6    18    17    29     -     -  30 臺北市  1 一般
# 835    14    37    13    25     -     -     -     -  30 臺北市  1 一般
# 836     -     -     -     -     -     -   185   128  30 臺北市  1 一般
# 837    15    39    20    20     -     -     -     -  30 臺北市  1 一般
#
# [5 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['學校代碼', '學校名稱', '日間∕進修別', '等級別', '一年級男生', '一年級女生', '二年級男生', '二年級女生',
#        '三年級男生', '三年級女生', '四年級男生', '四年級女生', '五年級男生', '五年級女生', '六年級男生', '六年級女生',
#        '七年級男生', '七年級女生', '延修生男生', '延修生女生', '縣市名稱', '體系別'],
#       dtype='object')

# %%
df["學校名稱"]=="國立東華大學"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 808    False
# 809    False
# 810    False
# 811    False
# 812    False
# 813    False
# 814    False
# 815    False
# 816    False
# 817    False
# 818    False
# 819    False
# 820    False
# 821    False
# 822    False
# 823    False
# 824    False
# 825    False
# 826    False
# 827    False
# 828    False
# 829    False
# 830    False
# 831    False
# 832    False
# 833    False
# 834    False
# 835    False
# 836    False
# 837    False
# Name: 學校名稱, Length: 838, dtype: bool

# %%
df[df["學校名稱"]=="國立東華大學"]
# Out:
#     學校代碼    學校名稱 日間∕進修別   等級別  一年級男生  一年級女生 二年級男生 二年級女生 三年級男生 三年級女生    ...     \
# 76    20  國立東華大學    D 日  D 博士   27.0   20.0    60    25    27    25    ...
# 77    20  國立東華大學    D 日  M 碩士  238.0  236.0   292   250   171   144    ...
# 78    20  國立東華大學    D 日  B 學士  890.0  945.0   841   950   883   933    ...
# 79    20  國立東華大學    N 職  M 碩士   74.0   80.0    90   104    42    51    ...
#
#    五年級女生 六年級男生 六年級女生 七年級男生 七年級女生 延修生男生 延修生女生    縣市名稱   體系別    一年級男女比
# 76    13    21     9    20    14     -     -  15 花蓮縣  1 一般  1.350000
# 77     6     -     7     -     -     -     -  15 花蓮縣  1 一般  1.008475
# 78     -     -     -     -     -   264   172  15 花蓮縣  1 一般  0.941799
# 79    20    15    21     1     -     -     -  15 花蓮縣  1 一般  0.925000
#
# [4 rows x 23 columns]

# %%
freshman = df[df.等級別 == "B 學士"].一年級男生
freshman
# Out:
# 2        897
# 6      1,091
# 11     2,096
# 13         -
# 16       866
# 20     1,691
# 24     1,108
# 26        79
# 29       902
# 33       972
# 37       713
# 41       978
# 44        58
# 47       847
# 51       398
# 55       615
# 59       217
# 63       643
# 65       207
# 68       946
# 70       345
# 73       562
# 78       890
# 82       525
# 125      154
# 131      149
# 134      120
# 137      433
# 139       22
# 142      730
#        ...
# 364      614
# 366       28
# 369      513
# 401      235
# 405      387
# 411      444
# 414        -
# 439      757
# 442      136
# 454      513
# 480      260
# 483       75
# 532      832
# 534      102
# 536      497
# 538      158
# 541      334
# 589      359
# 591      162
# 638      211
# 640       62
# 715       95
# 720       97
# 747       74
# 748        -
# 772      260
# 775       78
# 810       39
# 813        8
# 836      580
# Name: 一年級男生, Length: 107, dtype: object

# %%
df['一年級男女比'] = df.一年級男生/df.一年級女生

# %%
df[B][["學校名稱", "一年級男女比", "一年級男生","一年級女生"]].sort_values(by="一年級男女比")
# Out:
#            學校名稱    一年級男女比   一年級男生   一年級女生
# 174      國立臺南大學  0.083333     1.0    12.0
# 131    國立臺灣藝術大學  0.375315   149.0   397.0
# 134    國立臺灣藝術大學  0.454545   120.0   264.0
# 167    國立臺南藝術大學  0.461538    60.0   130.0
# 810       馬偕醫學院  0.475610    39.0    82.0
# 411      中山醫學大學  0.484716   444.0   916.0
# 342        實踐大學  0.485919   880.0  1811.0
# 345        實踐大學  0.513605   151.0   294.0
# 332        世新大學  0.514157   799.0  1554.0
# 401        慈濟大學  0.526906   235.0   446.0
# 532        亞洲大學  0.544147   832.0  1529.0
# 177    國立臺北教育大學  0.544954   297.0   545.0
# 181    國立臺中教育大學  0.575581   297.0   516.0
# 297        靜宜大學  0.631448  1016.0  1609.0
# 338        銘傳大學  0.632211  1633.0  2583.0
# 269        東吳大學  0.646643  1098.0  1698.0
# 65       國立臺北大學  0.646875   207.0   320.0
# 26       國立中興大學  0.647541    79.0   122.0
# 125    國立臺北藝術大學  0.649789   154.0   237.0
# 266        輔仁大學  0.651240   394.0   605.0
# 272        東吳大學  0.664179    89.0   134.0
# ...

# %%
big_school.sum()
# Out:
# 47

# %%
big_school = df.一年級男生 + df.一年級女生 > 1300
df[B & big_school][["學校名稱", "一年級男女比", "一年級男生","一年級女生"]].sort_values(by="一年級男女比")
# Out:
#          學校名稱    一年級男女比   一年級男生   一年級女生
# 411    中山醫學大學  0.484716   444.0   916.0
# 342      實踐大學  0.485919   880.0  1811.0
# 332      世新大學  0.514157   799.0  1554.0
# 532      亞洲大學  0.544147   832.0  1529.0
# 297      靜宜大學  0.631448  1016.0  1609.0
# 338      銘傳大學  0.632211  1633.0  2583.0
# 269      東吳大學  0.646643  1098.0  1698.0
# 245    國立屏東大學  0.670030   664.0   991.0
# 2      國立政治大學  0.690531   897.0  1299.0
# 263      輔仁大學  0.761081  1803.0  2369.0
# 439      長榮大學  0.807036   757.0   938.0
# 16   國立臺灣師範大學  0.811621   866.0  1067.0
# 258      東海大學  0.814254  1451.0  1782.0
# 63     國立臺北大學  0.849406   643.0   757.0
# 78     國立東華大學  0.941799   890.0   945.0
# 286    中國文化大學  0.963380  2394.0  2485.0
# 326      義守大學  1.006653  1513.0  1503.0
# 68     國立嘉義大學  1.007455   946.0   939.0
# 280      淡江大學  1.057603  2497.0  2361.0
# 6      國立清華大學  1.155720  1091.0   944.0
# 47     國立中正大學  1.163462   847.0   728.0
# 316      大葉大學  1.202788   949.0   789.0
# ...

# %%
result = df[B & big_school][["學校名稱", "一年級男女比"]].sort_values(by="一年級男女比")

# %%
result.plot.bar()

# %%
(df.一年級男女比 > 1).mean()
# Out:
# 0.4451073985680191

# %%
f =  df[df.等級別 == "B 學士"].一年級女生
f = f.str.replace(",", "")
pd.to_numeric(f[f.str.isnumeric()]).mean()
# Out:
# 573.3980582524272

# %%
df.head()
# Out:
#    學校代碼    學校名稱 日間∕進修別   等級別  一年級男生   一年級女生 二年級男生  二年級女生 三年級男生  三年級女生  \
# 0     1  國立政治大學    D 日  D 博士   90.0    82.0   102     59    85     58
# 1     1  國立政治大學    D 日  M 碩士  685.0   760.0   571    699   369    456
# 2     1  國立政治大學    D 日  B 學士  897.0  1299.0   888  1,348   997  1,226
# 3     1  國立政治大學    N 職  M 碩士  295.0   278.0   264    280   163    185
# 4     2  國立清華大學    D 日  D 博士  220.0    77.0   211     83   196     58
#
#      ...    五年級女生 六年級男生 六年級女生 七年級男生 七年級女生 延修生男生 延修生女生    縣市名稱   體系別    一年級男女比
# 0    ...       54    72    37    81    35     -     -  30 臺北市  1 一般  1.097561
# 1    ...        -     -     -     -     -     -     -  30 臺北市  1 一般  0.901316
# 2    ...        -     -     -     -     -   294   453  30 臺北市  1 一般  0.690531
# 3    ...       49     -     -     -     -     -     -  30 臺北市  1 一般  1.061151
# 4    ...       43   119    45   186    69     -     -  18 新竹市  1 一般  2.857143
#
# [5 rows x 23 columns]

# %%
df.loc[4]["四年級女生"]
# Out:
# '59'

# %%
B = df.等級別 == "B 學士"
df.一年級男生 = df.一年級男生.str.replace(",", "")
df.一年級女生 = df.一年級女生.str.replace(",", "")

#pd.to_numeric(f[f.str.isnumeric()]).mean()

# %%
df.一年級男生 = pd.to_numeric(df.一年級男生, errors="coerce")
df.一年級女生 = pd.to_numeric(df.一年級女生, errors="coerce")

# %%
df[df.一年級男生.str.isnumeric() & df.一年級女生.str.isnumeric() & B]
# Out:
#      學校代碼       學校名稱 日間∕進修別   等級別 一年級男生 一年級女生  二年級男生  二年級女生  三年級男生  三年級女生  \
# 2       1     國立政治大學    D 日  B 學士   897  1299    888  1,348    997  1,226
# 6       2     國立清華大學    D 日  B 學士  1091   944  1,164  1,003  1,110  1,044
# 11      3     國立臺灣大學    D 日  B 學士  2096  1642  2,124  1,651  2,086  1,614
# 16      4   國立臺灣師範大學    D 日  B 學士   866  1067    863  1,094    836  1,055
# 20      5     國立成功大學    D 日  B 學士  1691  1026  1,713  1,039  1,656    968
# 24      6     國立中興大學    D 日  B 學士  1108   806  1,124    799  1,165    814
# 26      6     國立中興大學    P 進  B 學士    79   122    101    114     82    127
# 29      7     國立交通大學    D 日  B 學士   902   411    924    411    932    380
# 33      8     國立中央大學    D 日  B 學士   972   531    949    532    934    524
# 37      9     國立中山大學    D 日  B 學士   713   394    689    439    695    427
# 41     12   國立臺灣海洋大學    D 日  B 學士   978   442    945    433    970    410
# 44     12   國立臺灣海洋大學    P 進  B 學士    58    51     67     53     70     51
# ...
