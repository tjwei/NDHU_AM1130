# %%
from PIL import Image
import numpy as np
# %matplotlib inline 
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use('bmh')
matplotlib.rcParams['figure.figsize']=(8,5)

# %%
# 產生隨機數據
X = np.random.normal(0, 3, size=(50,1))
Y = X @ [1] + np.random.normal(0, size=50)
# 畫出來看看
plt.plot(X, Y, 'o');
# Out:
# <img src="data:image/png;base64,..." width="576">

# %%
a = np.linalg.lstsq(X, Y)[0]
plt.plot(X, X @ a, 'rx');

# %% [markdown]
# Use SKLearn

# %%
from sklearn import linear_model

# %%
X = np.random.normal(0, 3, size=(50,1))
Y = X @ [3] + 4 +np.random.normal(0, size=50)
plt.plot(X, Y, 'o');

# %%
regr = linear_model.LinearRegression()
regr
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
regr.fit(X, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# 畫出來
plt.plot(X, Y, 'bo')
plt.plot(X, regr.predict(X), 'rx');

# %%
from sklearn import datasets

# %%
diabetes  = datasets.load_diabetes()

# %%
datasets.load_diabetes?

# %%
import scipy.stats

# %%
scipy.stats.describe(diabetes.target)
# Out:
# DescribeResult(nobs=442, minmax=(25.0, 346.0), mean=152.13348416289594, variance=5943.331347923785, skewness=0.43906639932477265, kurtosis=-0.8866436055681386)

# %%
regr.fit(diabetes.data, diabetes.target)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
plt.plot(diabetes.data[:, 2], diabetes.target, 'bo')
plt.plot(diabetes.data[:, 2], regr.predict(diabetes.data), 'rx')

# %%
plt.plot(diabetes.target, regr.predict(diabetes.data), 'rx')
