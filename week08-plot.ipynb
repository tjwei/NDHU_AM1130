# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-np.pi, np.pi, 100)
x

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.abs(x))

# %%
plt.style.use('bmh')

# %%
plt.style.available

# %%
plt.plot(x, x**2, 'b.', label='x^2')
plt.plot(x, np.sin(x), 'g', label='sin(x)')
plt.plot(x, np.abs(x), 'k', label='|x|')
plt.legend()

# %%
with plt.xkcd():
    plt.plot(x, np.sin(x));

# %%
# %matplotlib notebook

# %%
from mpl_toolkits.mplot3d import Axes3D
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
Z = np.sin(np.sqrt(X**2 + Y**2))

ax = plt.gca(projection='3d')
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=plt.cm.afmhot, linewidth=0.2)
plt.show()

# %%
# !wget https://raw.githubusercontent.com/tjwei/class2016/master/img/e_crop.png
# Out:
# --2017-11-06 05:46:49--  https://raw.githubusercontent.com/tjwei/class2016/master/img/e_crop.png
# Resolving webproxy (webproxy)... 10.116.88.53
# Connecting to webproxy (webproxy)|10.116.88.53|:3128... connected.
# Proxy request sent, awaiting response... 200 OK
# Length: 714409 (698K) [image/png]
# Saving to: 'e_crop.png'
#
# e_crop.png          100%[===================>] 697.67K  4.50MB/s    in 0.2s
#
# 2017-11-06 05:46:50 (4.50 MB/s) - 'e_crop.png' saved [714409/714409]

# %%
from PIL import Image
Image.open("9326960.png").resize((100,100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FDB8DB05BA8>

# %%
# %matplotlib notebook

# %%
from mpl_toolkits.mplot3d import Axes3D
X = np.arange(0, 100, 1)
Y = np.arange(0, 100, 1)
X, Y = np.meshgrid(X, Y)
img = Image.open("9326960.png").resize((100,100))
img = img.convert('L')
Z = np.array(img)/255

ax = plt.gca(projection='3d')
surf = ax.plot_surface(X, Y, Z, rstride=3, 
                       cstride=3, cmap=plt.cm.autumn, linewidth=1)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">
