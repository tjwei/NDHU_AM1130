# %%
import facebook

# %% [markdown]
# 取得 token https://developers.facebook.com/tools/explorer

# %%
token="EAACEdEose0cBABOC5xSnJWtI6T8DB0UGxZB4zGWBDm8gfM4COMA1lwQqC3Q1oMfbJIyzzF65UiMNQAcutBd14v2JXl5ARnXN5Hf9MFM76OmxR1y11YiYK4d8HZCivb3BVaoTNkfFJvVznFBluOIDVpNyqry53IBrYSus0CDIQ6wGfZCZCogSAm57tdxZCc174BsFefD8ykgZDZD"

# %%
graph = facebook.GraphAPI(token, version="2.7")

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot?

# %%
with plt.xkcd():
    pass
plt.figure(figsize=(5,5))
t = np.linspace(0, 2*np.pi, 101)
plt.plot(np.cos(t), np.sin(t), 'r--')
plt.plot(.7*np.cos(t), .7*np.sin(t), 'r')
plt.plot(1.3*np.cos(t), 1.3*np.sin(t), 'r')

for i in range(8):
    t0 = 2*np.pi/8*i
    x0,y0 = 1.15*np.cos(t0), 1.15*np.sin(t0)
    plt.plot(.15*np.cos(t)+x0, .15*np.sin(t)+y0, 'r')

    

t = np.linspace(0, 4*np.pi, 6)
plt.plot(.7*np.cos(t+np.pi/10), .7*np.sin(t+np.pi/10), 'r')
t = np.linspace(0, 2*np.pi, 5)
plt.plot(np.cos(t), np.sin(t), 'r:')
plt.plot(np.cos(t+np.pi/4), np.sin(t+np.pi/4), 'r.')


t = np.linspace(0, 2*np.pi, 9)
plt.plot(1.15*np.cos(t), 1.15*np.sin(t), 'rp')
plt.savefig('circle.png')
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['xkcd', 'Humor Sans', 'Comic Sans MS'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
import json
 # "SELF", "ALL_FRIENDS" OR "EVERYONE".
privacy = json.dumps({"value": "EVERYONE"})
graph.put_photo(image=open('circle.png', 'rb'), 
                caption='軟體實作魔法陣範例', privacy=privacy)
# Out:
# {'id': '10209056704449604', 'post_id': '10201382289514027_10209056704449604'}
